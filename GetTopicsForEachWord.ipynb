# %% [markdown]
# # Get Topics for Each Word

# %% [markdown]
# Here is a script that I used to get the topics for each word. Then I used the most popular topic for each word to make a more simplified topic modeling in my website: https://sarajaksa.eu/2019/meicogsci-topics/text-modeling/

# %%
# import the libaries
import gensim
import collections
import os
import nltk
import json
import pandas
from constants import folder_meicogsci, folder_meicogsci_2019, folder_models, all_topics_names

# %%
# import the model
model_21 = gensim.models.LdaModel.load(os.path.join(folder_models, "LDA_21"))
model_21.minimum_probability = 0.0

# %%
# for each topic get the most representitive 500 words
all_topics = model_21.show_topics(num_topics=-1, num_words=500, formatted=False)

# %%
# put the words in the dict of wich, with word having the dict of topics
all_words = collections.defaultdict(dict)
for topic, words in all_topics:
    for word, freq in words:
        all_words[word][all_topics_names[topic]] = float(freq)

# %% [markdown]
# Below are some examples of the words and their topics.

# %%
all_words["negative emotion"]
# Out:
# {'reinforcment learning': 0.0003554156864993274}

# %%
all_words["cognitive scientist"]
# Out:
# {'verbalization': 0.001178124570287764, 'reasoning': 0.001995381899178028}

# %%
all_words["morality"]
# Out:
# {'decision making': 0.0021055189426988363}

# %%
all_words["neurological"]
# Out:
# {'pitch': 0.0037964843213558197,
#  'non-typical': 0.0016196452779695392,
#  'neuroscience': 0.0010986431734636426,
#  'constructivism': 0.0005386153934523463,
#  'learning': 0.0007708182674832642,
#  'attention': 0.0008897276129573584,
#  'TMS': 0.0004845411458518356}

# %%
# this is a json dump of all words with all topics
json.dumps(all_words)
# Out:
# '{"language": {"pitch": 0.016879143193364143, "categorization": 0.004162071738392115, "modeling": 0.005567881278693676, "non-typical": 0.0004919379134662449, "verbalization": 0.007837525568902493, "language": 0.05771108344197273, "reasoning": 0.0006777359521947801, "system": 0.01090843416750431}, "speech": {"pitch": 0.012216161005198956, "health": 0.006021290086209774, "verbalization": 0.006537938490509987, "language": 0.004639361519366503, "system": 0.002979497192427516, "neural networks": 0.000795051222667098}, "brain": {"pitch": 0.0121036721393466, "movement": 0.007805631961673498, "society": 0.0008395765325985849, "neuroscience": 0.027518950402736664, "health": 0.0014513020869344473, "perception": 0.0014325991505756974, "learning": 0.0010376477148383856, "verbalization": 0.005948040634393692, "reasoning": 0.0023951425682753325, "attention": 0.0017139205010607839, "system": 0.000984728685580194, "tasks": 0.002667863853275776, "TMS": 0.023137787356972694, "neural networks": 0.0066892835311591625, "reinforcment learning": 0.00040999194607138634}, "tone": {"pitch": 0.011285021901130676, "perception": 0.0006096523138694465, "verbalization": 0.004062274936586618}, "ability": {"pitch": 0.01060825027525425, "movement": 0.0007416176376864314, "categorization": 0.003956661093980074, "modeling": 0.00282310601323843, "society": 0.001945299911312759, "decision making": 0.0011473626364022493, "neuroscience": 0.002469601109623909, "constructivism": 0.001638570916838944, "health": 0.0027021386194974184, "learning": 0.00589816365391016, "reasoning": 0.0019130846485495567, "attention": 0.005076921544969082, "system": 0.004333212040364742, "tasks": 0.003687586635351181, "neural networks": 0.002672609407454729, "reinforcment learning": 0.001127977971918881}, "human": {"pitch": 0.010229079984128475, "movement": 0.004253252875059843, "categorization": 0.005405213218182325, "modeling": 0.012560405768454075, "society": 0.01918940804898739, "decision making": 0.003126000752672553, "non-typical": 0.00044780419557355344, "neuroscience": 0.003949126228690147, "constructivism": 0.005312863737344742, "perception": 0.008461087942123413, "learning": 0.0010632433695718646, "language": 0.0012619177578017116, "reasoning": 0.002948890905827284, "attention": 0.006783844903111458, "system": 0.01858159899711609, "TMS": 0.0009457795531488955, "neural networks": 0.003737359307706356, "reinforcment learning": 0.004648133646696806}, "pitch": {"pitch": 0.009463715367019176}, "native": {"pitch": 0.009209605865180492, "language": 0.005705725401639938, "tasks": 0.0005944574950262904}, "musical": {"pitch": 0.009050639346241951, "neuroscience": 0.0005882424884475768, "verbalization": 0.001128409756347537, "system": 0.00046923442278057337}, "perception": {"pitch": 0.008275005966424942, "movement": 0.006077269092202187, "categorization": 0.004965711385011673, "modeling": 0.004740156698971987, "neuroscience": 0.0011000646045431495, "constructivism": 0.0022078778129070997, "perception": 0.0018494322430342436, "verbalization": 0.004382313694804907, "reasoning": 0.005128927528858185, "attention": 0.005090374033898115, "system": 0.001200284925289452, "tasks": 0.0007714577950537205}, "music": {"pitch": 0.00808169785887003, "non-typical": 0.007605660241097212, "constructivism": 0.0037506811786442995, "verbalization": 0.000912124989554286, "system": 0.004344241227954626}, "effect": {"pitch": 0.007846351712942123, "movement": 0.0011013696203008294, "categorization": 0.0028685457073152065, "society": 0.0009992150589823723, "decision making": 0.00653134286403656, "non-typical": 0.006383232772350311, "neuroscience": 0.00927951280027628, "constructivism": 0.0012645232491195202, "health": 0.020519157871603966, "perception": 0.012119040824472904, "learning": 0.005897843278944492, "verbalization": 0.0016210098983719945, "language": 0.003975077997893095, "reasoning": 0.0022850504610687494, "attention": 0.006596470717340708, "tasks": 0.004173783119767904, "TMS": 0.011302283965051174, "neura ...

# %%
# create a dictionary with word and their most popular topic
word_with_topic = dict([(word, list(pandas.DataFrame([(t, c) for t, c in topics.items()]).sort_values(by=1).tail(1)[0])[0]) for word, topics in all_words.items()])

# %%
# here are some rown with words and their most populat opic
pandas.DataFrame([(w, t) for w, t in word_with_topic.items()], columns=["Word", "Topic"]).head(10)
# Out:
#          Word         Topic
# 0    language      language
# 1      speech         pitch
# 2       brain  neuroscience
# 3        tone         pitch
# 4     ability         pitch
# 5       human       society
# 6       pitch         pitch
# 7      native         pitch
# 8     musical         pitch
# 9  perception         pitch

# %%
# and this is a json dump with words and their most popular topic
json.dumps(word_with_topic)
# Out:
# '{"language": "language", "speech": "pitch", "brain": "neuroscience", "tone": "pitch", "ability": "pitch", "human": "society", "pitch": "pitch", "native": "pitch", "musical": "pitch", "perception": "pitch", "music": "pitch", "effect": "health", "context": "pitch", "difference": "attention", "feature": "perception", "hypothesis": "pitch", "stroke": "pitch", "test": "health", "second": "pitch", "class": "pitch", "task": "learning", "speaker": "language", "curiosity": "pitch", "english": "language", "stimulus": "perception", "grammar": "pitch", "protein": "pitch", "population": "pitch", "correlation": "pitch", "critical": "pitch", "experiment": "categorization", "specie": "pitch", "imitation": "pitch", "probe": "pitch", "many": "neural networks", "vocal": "pitch", "syndrome": "pitch", "musician": "pitch", "dementia": "pitch", "patient": "non-typical", "adult": "neuroscience", "question": "constructivism", "time": "health", "infant": "pitch", "mechanism": "reinforcment learning", "german": "pitch", "significant": "attention", "learner": "pitch", "sample": "pitch", "subject": "perception", "non": "non-typical", "neurological": "pitch", "similar": "pitch", "auditory": "pitch", "lesson": "pitch", "skill": "pitch", "relationship": "tasks", "order": "perception", "aptitude": "pitch", "interval": "pitch", "accent": "pitch", "factor": "society", "second language": "pitch", "talent": "pitch", "higher": "tasks", "data": "movement", "various": "pitch", "phrase": "pitch", "illusion": "pitch", "number": "attention", "major": "pitch", "prosody": "pitch", "individual": "society", "error": "verbalization", "session": "health", "neural": "neural networks", "training": "neural networks", "influence": "health", "progression": "pitch", "tissue": "pitch", "possible": "reinforcment learning", "frequency": "verbalization", "phenomenon": "verbalization", "learning": "reinforcment learning", "first": "language", "culture": "pitch", "memory": "health", "age": "learning", "prosodic": "pitch", "certain": "pitch", "motivation": "reinforcment learning", "capacity": "reasoning", "rat": "verbalization", "combination": "language", "aphasia": "pitch", "slovak": "tasks", "right": "movement", "size": "pitch", "localization": "pitch", "acquisition": "language", "rate": "non-typical", "participant": "non-typical", "reaction": "perception", "sensitivity": "attention", "pathway": "perception", "questionnaire": "decision making", "aim": "non-typical", "mathematics": "modeling", "disorder": "non-typical", "impairment": "learning", "common": "learning", "following": "pitch", "region": "neuroscience", "sequence": "perception", "reaction time": "perception", "cultural": "learning", "comparison": "perception", "contrast": "movement", "amount": "attention", "due": "attention", "process": "constructivism", "understanding": "society", "neurological disorder": "pitch", "evolution": "modeling", "universal": "verbalization", "method": "neuroscience", "conclusion": "non-typical", "natural": "system", "important": "decision making", "human brain": "pitch", "development": "society", "gene": "pitch", "linguistic": "language", "child": "learning", "type": "reinforcment learning", "high": "attention", "stem": "pitch", "small": "reinforcment learning", "others": "tasks", "pattern": "neural networks", "imaging": "TMS", "theory": "modeling", "processing": "language", "researcher": "constructivism", "way": "system", "function": "neuroscience", "several": "categorization", "system": "system", "energy": "neural networks", "efficiency": "pitch", "flow": "pitch", "support": "pitch", "addition": "neuroscience", "necessary": "pitch", "analysis": "society", "case": "system", "component": "categorization", "scanner": "pitch", "hand": "non-typical", "interest": "society", "state": "reinforcment learning", "finding": "verbalization", "paper": "health", "foreign": "language", "ratio": "movement", "instrument": "pitch", "psychology": "categorization", "level": "tasks", "main": "reinforcment learning",  ...
